# %%
import pandas as pd
from pymongo import MongoClient, GEO2D
import pymongo
import json
import datetime
from bson.son import SON
import folium 
import math
import numpy as np
from IPython.display import display

# %%
#Create a link to MongoDB using MongoClient(The name of new database will be morte_motoquiro_event)
db = MongoClient().morte_motoquiro_event

# %%
# Create the collection "dados20150817_line_172" with an geolocation index "latlon"
db.dados20150817_line_172.create_index([("latlon", GEO2D)])
# Out:
# u'latlon_2d'

# %%
# Create the collection "dados20150817_line_316" with an geolocation index "latlon"
db.dados20150817_line_316.create_index([("latlon", GEO2D)])
# Out:
# u'latlon_2d'

# %%
# Create the collection "dados20150817_line_317" with an geolocation index "latlon"
db.dados20150817_line_317.create_index([("latlon", GEO2D)])
# Out:
# u'latlon_2d'

# %%
# Create the collection "dados20150817_line_957" with an geolocation index "latlon"
db.dados20150817_line_957.create_index([("latlon", GEO2D)])
# Out:
# u'latlon_2d'

# %%
df_20150817 = pd.read_csv('/home/kathrin/Doctorado/bus_rio/Datos_Omnibus/morte_motoqueiro_20150817/20150817.txt', delimiter = ('\t'))

df_20150817_line_172 = df_20150817[(df_20150817['line']=='172')]

# %%
df_20150817_line_316 = df_20150817[(df_20150817['line']=='316')]

# %%
df_20150817_line_317 = df_20150817[(df_20150817['line']=='317')]

# %%
df_20150817_line_957 = df_20150817[(df_20150817['line']=='957')]

# %%
#Insert in MongoDb gps data of bus line 172 on 2015-08-17


for row in df_20150817_line_172.iterrows():
    #The 'latitude' and 'longitude' names correspond to column names in the original cceats dataframe
    df_20150817_line_172_file = [{"timestamp": row[1]['timestamp'],
                                  "bus_id":row[1]['bus_id'],
                                  "line":row[1]['line'],
                                  "latitude": row[1]['latitude'],
                                  "longitude": row [1]['longitude'], 
                                  "speed" : row[1]['speed'],
                                  "latlon": [ row[1]['longitude'], row[1]['latitude'] ]
                                  }]
    db.dados20150817_line_172.insert_many(df_20150817_line_172_file)

# %%
len(df_20150817_line_172)
# Out:
# 15855

# %%
#Insert in MongoDb gps data of bus line 316 on 2015-08-17
df_20150817_line_316_file = []

for row in df_20150817_line_316.iterrows():
    #The 'latitude' and 'longitude' names correspond to column names in the original cceats dataframe
    df_20150817_line_316_file = [{"timestamp": row[1]['timestamp'],
                                  "bus_id":row[1]['bus_id'],
                                  "line":row[1]['line'],
                                  "latitude": row[1]['latitude'],
                                  "longitude": row [1]['longitude'], 
                                  "speed" : row[1]['speed'],
                                  "latlon": [ row[1]['longitude'], row[1]['latitude'] ]
                                  }]
    db.dados20150817_line_316.insert_many(df_20150817_line_316_file)

# %%
#Insert in MongoDb gps data of bus line 317 on 2015-08-17
df_20150817_line_317_file = []

for row in df_20150817_line_317.iterrows():
    #The 'latitude' and 'longitude' names correspond to column names in the original cceats dataframe
    df_20150817_line_317_file = [{"timestamp": row[1]['timestamp'],
                                  "bus_id":row[1]['bus_id'],
                                  "line":row[1]['line'],
                                  "latitude": row[1]['latitude'],
                                  "longitude": row [1]['longitude'], 
                                  "speed" : row[1]['speed'],
                                  "latlon": [ row[1]['longitude'], row[1]['latitude'] ]
                                  }]
    db.dados20150817_line_317.insert_many(df_20150817_line_317_file)

# %%
#Insert in MongoDb gps data of bus line 317 on 2015-08-17
df_20150817_line_957_file = []

for row in df_20150817_line_957.iterrows():
    #The 'latitude' and 'longitude' names correspond to column names in the original cceats dataframe
    df_20150817_line_957_file = [{"timestamp": row[1]['timestamp'],
                                  "bus_id":row[1]['bus_id'],
                                  "line":row[1]['line'],
                                  "latitude": row[1]['latitude'],
                                  "longitude": row [1]['longitude'], 
                                  "speed" : row[1]['speed'],
                                  "latlon": [ row[1]['longitude'], row[1]['latitude'] ]
                                  }]
    db.dados20150817_line_957.insert_many(df_20150817_line_957_file)

# %%
#calcula cuantos id diferentes que circularon de la linea 172 el dia 2015-08-17
df_20150817_line_172.groupby('line').bus_id.nunique()
# Out:
# line
# 172    24
# Name: bus_id, dtype: int64

# %%
#Lista todos los  bus_id diferentes de la linea 172 que circularon el dia 2015-08-17
pd.unique(df_20150817_line_172.bus_id.ravel())
# Out:
# array(['A41315', 'A41059', 'A55077', 'A41220', 'A41228', 'A41213',
#        'A41302', 'A41270', 'A41319', 'A41273', 'A41195', 'A41233',
#        'A41231', 'A55157', 'A41269', 'A55156', 'A41329', 'A41333',
#        'A55155', 'A55004', 'A41164', 'A41295', 'A55154', 'A41436'], dtype=object)

# %%
#otra forma de calcular la cantidad de bus_id diferentes circulando ese dia
#Function to compute the bus_ids circulating during a day 20150208 of bus line 172
def bus_id_list ():
    bus_id_20150817_172 = db.dados20150817_line_172.distinct("bus_id")
    return bus_id_20150817_172

# %%
busId_list = bus_id_list()
busId_list
# Out:
# [u'A41315',
#  u'A41059',
#  u'A55077',
#  u'A41220',
#  u'A41228',
#  u'A41213',
#  u'A41302',
#  u'A41270',
#  u'A41319',
#  u'A41273',
#  u'A41195',
#  u'A41233',
#  u'A41231',
#  u'A55157',
#  u'A41269',
#  u'A55156',
#  u'A41329',
#  u'A41333',
#  u'A55155',
#  u'A55004',
#  u'A41164',
#  u'A41295',
#  u'A55154',
#  u'A41436']

# %%
#Funcion para meter los bus_Id del dataframe para un array
def get_busId_list():
    array_busId = []
    for bus in busId_list:
        strbus = str(bus)
        array_busId.insert(len(array_busId), strbus)
    return array_busId

# %%
array_busId = get_busId_list()
array_busId
# Out:
# ['A41315',
#  'A41059',
#  'A55077',
#  'A41220',
#  'A41228',
#  'A41213',
#  'A41302',
#  'A41270',
#  'A41319',
#  'A41273',
#  'A41195',
#  'A41233',
#  'A41231',
#  'A55157',
#  'A41269',
#  'A55156',
#  'A41329',
#  'A41333',
#  'A55155',
#  'A55004',
#  'A41164',
#  'A41295',
#  'A55154',
#  'A41436']

# %%
#Punto inicial del omnibus 172 Central do Brasil
initial_point = (-22.903570, -43.191571)

# %%
inverted_initial_point = (-43.191571, -22.903570)

# %%
#Punto final del omnibus 172 Sao Conrado
final_point = (-22.998734, -43.269457)

# %%
inverted_final_point = (-43.269457, -22.998734)

# %%
#funcion que dado un el bus_id de un omnibus y un punto inicial/final devuelve los puntos mas cercanos a ese punto. 
# A esa función se le debería pasar también la BD, pero ahora no se va a hacer asi
def near_points_to_origin (bus_id, inverted_origin_point):
    near_initial_points_array = []
    #la funcion $within recibe las coordenadas en orden inverso (primero longitud y después latitud)
    for row in db.dados20150301_line_410.find({"latlon": {"$within": {"$center": [inverted_origin_point, 0.00052543]}}, "bus_id": bus_id}).sort("timestamp",pymongo.DESCENDING):
        near_initial_points_array.insert(0, [row[u'timestamp'], row[u'latitude'], row[u'longitude'], row[u'speed']])
    #convert the array in panda dataframe 
    sorted_near_initial_points = pd.DataFrame(near_initial_points_array, columns=['timestamp', 'latitude', 'longitude', 'speed'])
    return sorted_near_initial_points

# %%
#LLamada a la funcion near_points_to_origin para encontrar los puntos más cercanos al 
#punto initial_point(-22.903570, -43.191571) aqui se pasan a la inversa
sorted_near_final_points = near_points_to_origin ('A41315', inverted_final_point)
sorted_near_final_points
# Out:
# Empty DataFrame
# Columns: [timestamp, latitude, longitude, speed]
# Index: []

# %%
bus_A41315 = df_20150817_line_172[(df_20150817_line_172['bus_id']== 'A41315')]
bus_A41315
# Out:
#                   timestamp  bus_id line   latitude  longitude  speed
# 18      17-08-2015 00:00:02  A41315  172 -22.901779 -43.207924   0.19
# 670     17-08-2015 00:01:12  A41315  172 -22.901798 -43.207867   0.00
# 1990    17-08-2015 00:02:22  A41315  172 -22.901829 -43.208069   0.74
# 2565    17-08-2015 00:02:57  A41315  172 -22.901754 -43.208141   0.19
# 4132    17-08-2015 00:04:07  A41315  172 -22.901829 -43.208038   0.19
# 5952    17-08-2015 00:05:17  A41315  172 -22.901798 -43.207989   0.00
# 6856    17-08-2015 00:05:52  A41315  172 -22.901808 -43.208118   0.00
# 8927    17-08-2015 00:07:02  A41315  172 -22.901806 -43.208042   0.00
# 10993   17-08-2015 00:08:12  A41315  172 -22.901827 -43.208084   0.00
# 13009   17-08-2015 00:09:22  A41315  172 -22.901741 -43.208015   0.00
# 13847   17-08-2015 00:09:57  A41315  172 -22.901823 -43.207882   0.00
# 15843   17-08-2015 00:11:07  A41315  172 -22.901781 -43.207958   0.00
# ...

# %%
bus_A55077 = df_20150817_line_172[(df_20150817_line_172['bus_id']== 'A55077')]
bus_A55077
# Out:
#                    timestamp  bus_id line   latitude  longitude  speed
# 2155     17-08-2015 00:02:35  A55077  172 -22.906309 -43.261021      0
# 51742    17-08-2015 00:32:35  A55077  172 -22.906370 -43.261070      0
# 99771    17-08-2015 01:02:35  A55077  172 -22.906380 -43.261021      0
# 190902   17-08-2015 02:02:35  A55077  172 -22.906330 -43.261082      0
# 237905   17-08-2015 02:32:35  A55077  172 -22.906389 -43.261070      0
# 284778   17-08-2015 03:02:35  A55077  172 -22.906290 -43.260990      0
# 332319   17-08-2015 03:32:35  A55077  172 -22.906380 -43.261059      0
# 441348   17-08-2015 04:41:55  A55077  172 -22.905029 -43.192638      0
# 443573   17-08-2015 04:42:55  A55077  172 -22.904961 -43.192780      0
# 445177   17-08-2015 04:43:55  A55077  172 -22.905029 -43.192810      0
# 448571   17-08-2015 04:45:25  A55077  172 -22.904930 -43.193260      0
# 449098   17-08-2015 04:45:55  A55077  172 -22.904921 -43.193249      0
# ...

# %%
buses_parados= bus_A41315[(bus_A41315['speed'] < 10)]
buses_parados
# Out:
#                   timestamp  bus_id line   latitude  longitude  speed
# 18      17-08-2015 00:00:02  A41315  172 -22.901779 -43.207924   0.19
# 670     17-08-2015 00:01:12  A41315  172 -22.901798 -43.207867   0.00
# 1990    17-08-2015 00:02:22  A41315  172 -22.901829 -43.208069   0.74
# 2565    17-08-2015 00:02:57  A41315  172 -22.901754 -43.208141   0.19
# 4132    17-08-2015 00:04:07  A41315  172 -22.901829 -43.208038   0.19
# 5952    17-08-2015 00:05:17  A41315  172 -22.901798 -43.207989   0.00
# 6856    17-08-2015 00:05:52  A41315  172 -22.901808 -43.208118   0.00
# 8927    17-08-2015 00:07:02  A41315  172 -22.901806 -43.208042   0.00
# 10993   17-08-2015 00:08:12  A41315  172 -22.901827 -43.208084   0.00
# 13009   17-08-2015 00:09:22  A41315  172 -22.901741 -43.208015   0.00
# 13847   17-08-2015 00:09:57  A41315  172 -22.901823 -43.207882   0.00
# 15843   17-08-2015 00:11:07  A41315  172 -22.901781 -43.207958   0.00
# ...

# %%
"""Funciones para renderizar el mapa en el html"""
from IPython.display import HTML
 
def inline_map(map):
    """
    Embeds the HTML source of the map directly into the IPython notebook.
    
    This method will not work if the map depends on any files (json data). Also this uses
    the HTML5 srcdoc attribute, which may not be supported in all browsers.
    """
    map._build_map()
    return HTML('<iframe srcdoc="{srcdoc}" style="width: 100%; height: 510px; border: none"></iframe>'.format(srcdoc=map.HTML.replace('"', '&quot;')))
 
def embed_map(map, path="map.html"):
    """
    Embeds a linked iframe to the map into the IPython notebook.
    
    Note: this method will not capture the source of the map into the notebook.
    This method should work for all maps (as long as they use relative urls).
    """
    map.create_map(path=path)
    return HTML('<iframe src="files/{path}" style="width: 100%; height: 510px; border: none"></iframe>'.format(path=path))

# %%
onibus172_shapes = pd.read_csv('/home/kathrin/Doctorado/bus_rio/Datos_Omnibus/Onibus/Shapes/gtfs_linha172-shapes.csv')
myfmap172=folium.Map(location=[-22.9105, -43.1718], zoom_start=12)
locations172 = []
for row in onibus172_shapes.iterrows():
    #The 'latitude' and 'longitude' names correspond to column names in the original cceats dataframe
    locations172.insert(1, [ row[1]['latitude'], row[1]['longitude'] ])

myfmap172.line(locations172)
embed_map(myfmap172)
# Out:
# <iframe src="files/map.html" style="width: 100%; height: 510px; border: none"></iframe>

# %%
#pintando los puntos más cerca del punto final (Vila Isabel)
for row in buses_parados.iterrows():
    #The 'latitude' and 'longitude' names correspond to column names in the original cceats dataframe
    latlon = [ row[1]['latitude'], row[1]['longitude'] ]
    myfmap172.polygon_marker( latlon, fill_color='red', num_sides=4, radius=6)

embed_map(myfmap172)
# Out:
# <iframe src="files/map.html" style="width: 100%; height: 510px; border: none"></iframe>

# %%
#pintando los puntos más cerca del punto final (Vila Isabel)
for row in df_20150817_line_172.iterrows():
    #The 'latitude' and 'longitude' names correspond to column names in the original cceats dataframe
    latlon = [ row[1]['latitude'], row[1]['longitude'] ]
    myfmap172.polygon_marker( latlon, fill_color='green', num_sides=4, radius=6)

embed_map(myfmap172)
# Out:
# <iframe src="files/map.html" style="width: 100%; height: 510px; border: none"></iframe>
